# %%
import pandas as pd

# %%
import numpy as np

# %%
data = "C:/Users/jayne/OneDrive/Documents/University of San Diego/Capstone/winequality-white.txt"

# %%
df_white = pd.read_csv(data,sep = ';')

# %%
import seaborn as sns

# %%
from scipy import stats

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
color_white = np.repeat('white', 4898)

# %%
df_white['color'] = color_white

# %%
df_white.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality  color
# 0      8.8        6  white
# 1      9.5        6  white
# ...

# %%
data2 = "C:/Users/jayne/OneDrive/Documents/University of San Diego/Capstone/winequality-red.csv"

# %%
df_red = pd.read_csv(data2)

# %%
color_red = np.repeat('red', 1599)

# %%
df_red['color'] = color_red

# %%
df_red.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality color
# 0      9.4        5   red
# 1      9.8        5   red
# ...

# %%
df_combine = pd.concat([df_white,df_red], ignore_index=True)
df_combine.index
# Out:
# RangeIndex(start=0, stop=6497, step=1)

# %%
df_combine.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality  color
# 0      8.8        6  white
# 1      9.5        6  white
# ...

# %%
df_combine.tail()
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 6492            6.2             0.600         0.08             2.0      0.090
# 6493            5.9             0.550         0.10             2.2      0.062
# 6494            6.3             0.510         0.13             2.3      0.076
# 6495            5.9             0.645         0.12             2.0      0.075
# 6496            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 6492                 32.0                  44.0  0.99490  3.45       0.58
# 6493                 39.0                  51.0  0.99512  3.52       0.76
# 6494                 29.0                  40.0  0.99574  3.42       0.75
# 6495                 32.0                  44.0  0.99547  3.57       0.71
# 6496                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol  quality color
# ...

# %%
column = range(0,len(df_combine))

# %%
df_combine.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality  color
# 0      8.8        6  white
# 1      9.5        6  white
# ...

# %%
df_combine["Wine Number"] = range(0,len(df_combine))

# %%
df_combine.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality  color  Wine Number
# 0      8.8        6  white            0
# ...

# %%
df_combine.to_csv('C:/Users/jayne/OneDrive/Documents/University of San Diego/Capstone/winecombine.csv')

# %%
import numpy as np

# %%
df_combine.groupby('color').mean()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# color
# red         8.319637          0.527821     0.270976        2.538806
# white       6.854788          0.278241     0.334192        6.391415
#
#        chlorides  free sulfur dioxide  total sulfur dioxide   density  \
# color
# red     0.087467            15.874922             46.467792  0.996747
# white   0.045772            35.308085            138.360657  0.994027
#
#              pH  sulphates    alcohol   quality  Wine Number
# color
# red    3.311113   0.658149  10.422983  5.636023       5697.0
# white  3.188267   0.489847  10.514267  5.877909       2448.5

# %%
df_combine.groupby('color')['pH'].mean()
# Out:
# color
# red      3.311113
# white    3.188267
# Name: pH, dtype: float64

# %%
df_combine.groupby('color')['pH'].std()
# Out:
# color
# red      0.154386
# white    0.151001
# Name: pH, dtype: float64

# %%
pip install statsmodels
# Out:
# ...
#      ---------------------------------------- 9.1/9.1 MB 9.1 MB/s eta 0:00:00
# ...
#      ------------------------------------- 233.8/233.8 kB 14.0 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import statsmodels.tools.tools as statools
import statsmodels.api as sm

# %%
from statsmodels.stats.weightstats import ztest as ztest

# %%
ztest((df_combine.loc[df_combine['color'] == 'white'])['pH'],(df_combine.loc[df_combine['color'] == 'red'])['pH'],alternative='smaller')
# Out:
# (-28.09002558145285, 6.4845417720337635e-174)
